# %%
from models import networks

# %%
None==None
# Out:
# True

# %%
import torch

# %%
import matplotlib.pyplot as plt
class t:
    def __init__(self):
        self.beta = 0.005
        self.start_var=100
        a=[]
        for self.epoch in range(1,501):
            a.append(self.beta*(min(1,(0.001+((self.epoch-1)%100)/50.0))if self.epoch>self.start_var else 0.001))
            plt.plot(a)

# %%
t()
